# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\engin\Pycharm Projects\pythonProject\PandasProject\archive\medals_total.csv")

print(type(data))
print(data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    country_code        country                country_long  Gold Medal  \
# 0           USA  United States    United States of America          40
# 1           CHN          China  People's Republic of China          40
# 2           JPN          Japan                       Japan          20
# 3           AUS      Australia                   Australia          18
# 4           FRA         France                      France          16
# ..          ...            ...                         ...         ...
# 87          PER           Peru                        Peru           0
# 88          QAT          Qatar                       Qatar           0
# 89          SGP      Singapore                   Singapore           0
# 90          SVK       Slovakia                    Slovakia           0
# 91          ZAM         Zambia                      Zambia           0
#
#     Silver Medal  Bronze Medal  Total
# ...

# %%
df.head()
# Out:
#   country_code        country                country_long  Gold Medal  \
# 0          USA  United States    United States of America          40
# 1          CHN          China  People's Republic of China          40
# 2          JPN          Japan                       Japan          20
# 3          AUS      Australia                   Australia          18
# 4          FRA         France                      France          16
#
#    Silver Medal  Bronze Medal  Total
# 0            44            42    126
# 1            27            24     91
# 2            12            13     45
# 3            19            16     53
# 4            26            22     64

# %%
df.tail()
# Out:
#    country_code    country country_long  Gold Medal  Silver Medal  \
# 87          PER       Peru         Peru           0             0
# 88          QAT      Qatar        Qatar           0             0
# 89          SGP  Singapore    Singapore           0             0
# 90          SVK   Slovakia     Slovakia           0             0
# 91          ZAM     Zambia       Zambia           0             0
#
#     Bronze Medal  Total
# 87             1      1
# 88             1      1
# 89             1      1
# 90             1      1
# 91             1      1

# %%
import os
os.system("%clear")
# Out:
# 1

# %%
df.sort_values(by="Bronze Medal")
# Out:
#    country_code        country                country_long  Gold Medal  \
# 62          DMA       Dominica                    Dominica           1
# 63          PAK       Pakistan                    Pakistan           1
# 58          UGA         Uganda                      Uganda           1
# 57          LCA    Saint Lucia                 Saint Lucia           1
# 56          CHI          Chile                       Chile           1
# ..          ...            ...                         ...         ...
# 3           AUS      Australia                   Australia          18
# 4           FRA         France                      France          16
# 1           CHN          China  People's Republic of China          40
# 6           GBR  Great Britain               Great Britain          14
# 0           USA  United States    United States of America          40
#
#     Silver Medal  Bronze Medal  Total
# 62             0             0      1
# ...
